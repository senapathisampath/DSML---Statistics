# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#!pip install openpyxl

# %%
df_ = pd.read_excel(r'D:\DSML\3. Statistics\data_3.xlsx')  #importing excel sheet

# %%
df_.head()
# Out:
#           x         y
# 0  4.792464  5.465294
# 1  4.495052  4.089470
# 2  5.161569  5.407030
# 3  6.425300  6.453381
# 4  4.888931  4.667882

# %% [markdown]
# Finding the no. of rows and columns

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       500 non-null    float64
#  1   y       500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
#visualizing the dataset
plt.scatter(x= df_['x'] , y= df_['y'])  
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
#Sampling of data
import random
df1 = df_.sample(n=100)      #Sample of size = 100
df3 = df_.sample(n=100)      #Sample of size = 100
df2 = df_.sample(n=150)      #Sample of size = 150
df4 = df_.sample(n=150)      #Sample of size = 150
df5 = df_.sample(n=475)      #Sample of size = 475

# %%
#Comparing the mean of population and samples
a, b = df_.mean()
print('The mean of population is: x: {}, y:{}'.format(a,b))
a, b = df1.mean()
print('The mean of df1 is: x: {}, y:{}'.format(a,b))
a, b = df3.mean()
print('The mean of df3 is: x: {}, y:{}'.format(a,b))
a, b = df2.mean()
print('The mean of df2 is: x: {}, y:{}'.format(a,b))
a, b = df4.mean()
print('The mean of df4 is: x: {}, y:{}'.format(a,b))
a, b = df5.mean()
print('The mean of df5 is: x: {}, y:{}'.format(a,b))
# Out:
# The mean of population is: x: 5.082467729231954, y:4.9528964245044955
# The mean of df1 is: x: 5.264353859837817, y:5.035047197157284
# The mean of df3 is: x: 5.063512495213988, y:4.834349688014743
# The mean of df2 is: x: 5.349656270631429, y:5.168383120951865
# The mean of df4 is: x: 4.830708489047834, y:4.840461538633589
# The mean of df5 is: x: 5.064445746161189, y:4.937362017938941

# %%
#Comparing the median of population and samples
a, b = df_.median()
print('The median of population is: x: {}, y:{}'.format(a,b))
a, b = df1.median()
print('The median of df1 is: x: {}, y:{}'.format(a,b))
a, b = df2.median()
print('The median of df2 is: x: {}, y:{}'.format(a,b))
a, b = df5.median()
print('The median of df5 is: x: {}, y:{}'.format(a,b))
# Out:
# The median of population is: x: 5.05487549200244, y:4.978847078474789
# The median of df1 is: x: 5.217647789481973, y:4.819599365425477
# The median of df2 is: x: 5.0023581933085985, y:5.108070880718122
# The median of df5 is: x: 5.044668157030117, y:4.977106771755396

# %%
#Comparing the variance of population and samples
a, b = df_.var()
print('The variance of population is: x: {}, y:{}'.format(a,b))
a, b = df1.var()
print('The variance of df1 is: x: {}, y:{}'.format(a,b))
a, b = df2.var()
print('The variance of df2 is: x: {}, y:{}'.format(a,b))
a, b = df3.var()
print('The variance of df3 is: x: {}, y:{}'.format(a,b))
a, b = df4.var()
print('The variance of df4 is: x: {}, y:{}'.format(a,b))
a, b = df5.var()
print('The variance of df5 is: x: {}, y:{}'.format(a,b))
# Out:
# The variance of population is: x: 2.6625581887561562, y:2.63475813398542
# The variance of df1 is: x: 2.3930557248524447, y:2.37815264142884
# The variance of df2 is: x: 2.748728063115341, y:2.542950803449152
# The variance of df3 is: x: 2.0914591082585283, y:2.842853188712865
# The variance of df4 is: x: 2.154092409133947, y:2.6181683606714006
# The variance of df5 is: x: 2.6798586777590145, y:2.627169333811548

# %%
#Comparing the standard deviation of population and samples
a, b = df_.std()
print('The standard deviation of population is: x: {}, y:{}'.format(a,b))
a, b = df1.std()
print('The standard deviation of df1 is: x: {}, y:{}'.format(a,b))
a, b = df2.std()
print('The standard deviation of df2 is: x: {}, y:{}'.format(a,b))
a, b = df3.std()
print('The standard deviation of df3 is: x: {}, y:{}'.format(a,b))
a, b = df4.std()
print('The standard deviation of df4 is: x: {}, y:{}'.format(a,b))
a, b = df5.std()
print('The standard deviation of df5 is: x: {}, y:{}'.format(a,b))
# Out:
# The standard deviation of population is: x: 1.6317347176413683, y:1.62319380666186
# The standard deviation of df1 is: x: 1.5469504597279269, y:1.5421260134725825
# The standard deviation of df2 is: x: 1.6579288474223919, y:1.5946632257154336
# The standard deviation of df3 is: x: 1.446187784576584, y:1.6860762701351517
# The standard deviation of df4 is: x: 1.4676826663601186, y:1.6180755114244207
# The standard deviation of df5 is: x: 1.6370273906563122, y:1.6208545072928502

# %% [markdown]
# ## Statistics of the data

# %%
#Range of x
popu_range_x = df_['x'].max() - df_['x'].min()
popu_range_x
# Out:
# 13.725427048471568

# %%
#range of y
popu_range_y = df_['y'].max() - df_['y'].min()
popu_range_y
# Out:
# 11.593352800114099

# %%
maxy=df_['y'].max()
miny=df_['y'].min()
print('max y: {}'.format(maxy))
print('min y: {}'.format(miny))
maxx=df_['x'].max()
minx=df_['x'].min()
print('max x: {}'.format(maxx))
print('min x: {}'.format(minx))
# Out:
# max y: 10.58925243952102
# min y: -1.004100360593079
# max x: 12.2670245277286
# min x: -1.458402520742969

# %%
#percentile calculation
df_.quantile([0.10, 0.25, 0.5, 0.75,0.90, 1], axis=0)
# Out:
#               x          y
# 0.10   3.435130   3.284788
# 0.25   4.318981   4.218101
# 0.50   5.054875   4.978847
# 0.75   5.891603   5.782668
# 0.90   6.533381   6.592286
# 1.00  12.267025  10.589252

# %%
#Quartile distribution using boxplot
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.boxplot(df_['x'])
plt.xlabel('X')
plt.title("Boxplot of X")
plt.subplot(1,2,2)
plt.boxplot(df_['y'])
plt.xlabel('Y')
plt.title("Boxplot of Y")
# Out:
# Text(0.5, 1.0, 'Boxplot of Y')

# %%
#Visualizing histogram distribution of dataset

plt.figure(figsize=(12,4))   
plt.subplot(1,2,1)
df_['x'].plot.hist(bins=50, alpha= 0.5, color='orange' )
plt.title('Distribution of x')
plt.xlabel('x')


plt.subplot(1,2,2)
df_['y'].plot.hist(bins=50, alpha= 0.5, color='purple' )
plt.xlabel('y')
plt.title('Distribution of y')
# Out:
# Text(0.5, 1.0, 'Distribution of y')

# %% [markdown]
# # Skewness

# %% [markdown]
# <img src = skewness.png>

# %%
#calculating skewness
df_.skew()
# Out:
# x    0.041523
# y   -0.082802
# dtype: float64

# %% [markdown]
# # Kurtosis

# %% [markdown]
# <img src = kurtosis.jpg>

# %%
#Calculating kurtosis
df_.kurt()
# Out:
# x    3.346334
# y    2.454247
# dtype: float64

# %% [markdown]
# # Grouped Data

# %%
#grp = pd.DataFrame({'Min':[4.1, 4.6, 5.1, 5.6, 6.1, 6.6], 'Max':[4.5,5.0,5.5,6.0,6.5,7.0], 'frequency' :[8, 4, 10, 6, 7, 5]}, index = '1 2 3 4 5 6'.split())

# %%
#grp

# %%
#grp['mid point'] = (grp['Min']+grp['Max'])/2
#grp['Cumulative Frequency'] = grp['frequency'].cumsum()

# %%
#grp

# %%
#calculating mean 

#mean = ((grp['frequency']*grp['mid point']).sum(axis=0))/(grp['frequency'].sum(axis=0))

# %%
#calculating median
#L = grp[grp['Cumulative Frequency']== 22]['Min']
#n_2 = grp['frequency'].sum(axis=0)/2
#f = grp[grp['Cumulative Frequency']== 22]['frequency']
#c = 12
#h = 0.5
#median = ((n_2 - c)*h/f)+L
#print('Median is {}'.format(median.values))

# %% [markdown]
# # Outliers Detection

# %% [markdown]
# ## Standard Deviation Approach

# %%
x_arr= np.array(df_['x'])   #converting to array

# %%
def outliers(k):

    outlier=[]

    for i in range(0,500):
        diff= (abs(x_arr[i]- np.mean(df_['x'])))/ np.std(df_['x'])
        
        if diff > k:
            outlier.append(x_arr[i])
            
    print('Number of outliers in x: ',len(outlier))
    ser= pd.Series(outlier, index=range(1,len(outlier)+1))
    
    ol=[]
    
    for i in range(0,500):
        if x_arr[i] in outlier:
            ol.append('1')
        else:
            ol.append('0')
            
    df_['outliers']=ol
    sns.scatterplot(x='x',y='y',data=df_, hue='outliers')

# %%
k1 = outliers(1)  #For normally distributed data, k=1 represents 68.27% of the data
# Out:
# Number of outliers in x:  96

# %%
k2 = outliers(2)   #For normally distributed data, k=2 represents 95.45% of the data
# Out:
# Number of outliers in x:  40

# %%
k3 = outliers(3)    #For normally distributed data, k=3 represents 99.73% of the data
# Out:
# Number of outliers in x:  10

# %% [markdown]
# ## Median Absolute Deviation (MAD) approach

# %%
# Outliers using MAD approach

out=[]
count = 0
X = df_.iloc[:,0]  #extracting x-values
M = df_['x'].median()    #median of X
z= abs(X-M)
MAD= z.median()
for i in range(0,500):
    Zm= 0.6745*(X[i]-M)/MAD
    if Zm>3 or Zm<-3:
        out.append('1')
        count += 1
    else:
        out.append('0')      
df_['outliers']=out
print ('No. of outliers are: ', count)
sns.scatterplot(x='x',y='y',data=df_,hue='outliers')
# Out:
# No. of outliers are:  33
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ## Interquartile Approach

# %%
outliers = []
count = 0
iqr = df_['x'].quantile(0.75) - df_['x'].quantile(0.25)
a = df_['x'].quantile(0.75) + (1.5 * iqr)
b = df_['x'].quantile(0.25) - (1.5 * iqr)
for i in range(0,500):
    Zm= df_.iloc[i,0]
    if Zm>a or Zm<b:
        outliers.append('1')
        count += 1
    else:
        outliers.append('0')      
df_['outliers']=outliers
print ('No. of outliers are: ', count)
sns.scatterplot(x='x',y='y',data=df_,hue='outliers')
# Out:
# No. of outliers are:  41
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# # Expectation

# %%
##given
x = [0, 1, 2, 3, 4]
l = print(len(x))
p = [0.008, 0.076, 0.265, 0.411, 0.240]
e1= []
for i in range(len(x)):
    e2= x[i]*p[i]
    e1.append(e2)
Expected_value = sum(e1)
print('expectation is', Expected_value)
# Out:
# 5
# expectation is 2.799

# %%
#expectation of rolling a dice N times

N = 100 ##no.. of trials-1
roll = np.zeros(N)

for i in range(N):
    roll[i] = np.random.randint(1, 7) #filling up the sample space
  #  print(roll)
expectation = np.zeros(N)

for i in range(1, N):
    expectation[i] = np.mean(roll[0:i])
  #  print(expectation)


expected_value = np.mean(expectation)

print("Expectation is ", expected_value)
plt.plot(expectation)
plt.title("Expectation of the dice roll")
plt.xlabel("Number of Trials")
plt.ylabel("Expectation")
plt.show()
# Out:
# Expectation is  3.7998259263008918

# %%
import scipy as sc

# %%
dice = sc.stats.randint(1,7)

# %%
dice.pmf(4) #probability of getting 4 when we roll a dice
# Out:
# 0.16666666666666666

# %%
dice.cdf(5)  #probability of getting a number less than or equal to 5
# Out:
# 0.8333333333333334

# %% [markdown]
# # Covariance

# %% [markdown]
# <img src = covariance.png>

# %%
#covariance between values

data = {'A': [45,37,42,35,39],
        'B': [38,31,26,28,33],
        'C': [10,15,17,21,12]
        }

df = pd.DataFrame(data,columns=['A','B','C'])

covMatrix = df.cov()
sns.heatmap(covMatrix, annot=True, fmt='g')
# Out:
# <Axes: >

# %%
A = [45,37,42,35,39]
B = [38,31,26,28,33]
C = [10,15,17,21,12]

data = np.array([A,B,C])

covMatrix = np.cov(data)
print (covMatrix)
# Out:
# [[ 15.8    9.6  -12.  ]
#  [  9.6   21.7  -17.25]
#  [-12.   -17.25  18.5 ]]

# %% [markdown]
# # Correlation

# %%
data = {'A': [45,37,42,35,39],
        'B': [38,31,26,28,33],
        'C': [10,15,17,21,12]
        }

df = pd.DataFrame(data,columns=['A','B','C'])

corrMatrix = df.corr()

print (corrMatrix)

sns.heatmap(corrMatrix, annot=True)
plt.show()
# Out:
#           A         B         C
# A  1.000000  0.518457 -0.701886
# B  0.518457  1.000000 -0.860941
# C -0.701886 -0.860941  1.000000

# %% [markdown]
# ## Draw the samples from distribution

# %%
##Normal Distribution using scipy library
## reference: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html#:~:text=The%20location%20%28%20loc%29%20keyword%20specifies%20the%20mean.,them%20with%20details%20specific%20for%20this%20particular%20distribution.
from scipy.stats import norm
import matplotlib.pyplot as pyplot
from scipy.stats import norm
import pandas as pd
import numpy as np


#Norm_Dist= norm(loc=3, scale=5) # loc is mean, scale is standard deviation

# %%
# Let's draw 50 samples from it and arrange as a 4 by 5 array
#N_Dist = Norm_Dist.rvs(size=(1000)) # size will return the desired output shape or size
N_Dist = np.random.normal(loc=0.0, scale=1.0, size=1000)   # loc is mean, scale is standard deviation, size = output size


print("Samples from a Normal Distribution:", N_Dist)
pyplot.hist(N_Dist,color='purple')
# Out:
# Samples from a Normal Distribution: [-6.04451169e-01  1.25759455e+00  1.84237126e+00  5.58198278e-01
#   1.05457060e+00 -1.10469511e+00 -6.08900438e-01 -4.92848941e-01
#   3.94736030e-01 -1.05590509e+00  4.75168159e-01  1.02834301e+00
#   4.01782584e-01  1.71782651e-01  2.68402370e-02 -6.52165575e-01
#  -1.53301358e+00  4.24582565e-01  5.84464594e-01 -1.49370631e-02
#   1.42094998e+00  1.62267281e+00 -1.72869616e+00  2.65221662e-02
#   2.54173903e-01  4.82085335e-01 -8.85610697e-02  1.21086689e+00
#   7.07198835e-01  1.87381845e+00  1.20672078e+00  2.89777904e-01
#   4.51133664e-02 -1.84961909e+00 -7.23661583e-01 -3.24013290e-01
#   6.81836512e-01  9.56741069e-01 -4.40566140e-01 -4.55058012e-01
#   1.11321938e+00  1.72153301e+00 -2.20098617e+00 -1.01686887e-01
#   7.98044659e-01  6.20962233e-01 -3.23939303e-01 -6.42109910e-01
#  -1.10350876e+00 -1.41373803e+00  2.51595596e-01 -6.12041510e-01
#  -6.70215009e-01 -5.51947917e-01 -7.69737975e-02  8.88781448e-02
#  -1.46250013e-01 -1.41236455e+00 -1.50275828e-01 -7.20677788e-01
#   5.83259384e-02 -1.56273877e-01 -4.19739602e-01  1.59899881e+00
#  -8.10342176e-02 -1.42727710e+00  3.79742263e-01 -6.35946397e-01
#  -5.75275634e-01  1.48150791e+00 -2.98905407e-02 -4.49819331e-01
#  -1.96053304e-01 -7.20708260e-01  9.56006069e-01  1.10044575e+00
#   5.84994277e-01 -9.64998747e-01 -4.81901083e-02  1.29814465e+00
#   1.05934378e+00  7.09728230e-01 -2.45544529e-01  1.57648446e+00
#  -1.24156350e+00  9.28055521e-02  4.58832637e-01 -1.69625491e+00
#   3.13907201e-01  2.14264559e-01  2.01890823e-01  6.08936219e-01
#   6.42076444e-01 -8.71364152e-01  4.03768058e-01 -5.35042095e-02
#  -6.56433695e-01 -3.98354392e-01  1.18846835e+00 -1.34658226e+00
#  -4.43964095e-02  2.11631075e+00  8.58135551e-01 -4.58899904e-01
#   9.90658922e-01  1.17487467e+00 -1.37270186e+00 -1.30598334e+00
#  -1.48886879e+00  2.19024155e-01 -1.09944345e-01 -3.58416434e-01
#   4.22520603e-01 -8.27710456e-01  5.91501154e-01 -1.08302485e+00
#   3.27274416e-01  9.65256637e-01 -6.60508914e-01  1.26443661e+00
#  -1.94110442e+00 -9.95823946e-01  6.17602055e-01  6.59471281e-01
#  -1.82700687e-01  4.30191627e-01  1.26791471e+00  1.36657198e+00
#  -1.64331768e-01  2.17259094e+00 -1.53392901e-01 -5.49866118e-01
#   3.60997679e+00  9.40128778e-02 -1.37252459e+00  1.45959223e-02
#  -6.61278151e-01 -1.00779591e-01 -4.59775472e-01 -6.34873991e-01
#  -1.23385052e+00 -1.87844299e+00  3.96668706e-01  7.02771424e-01
#   7.07365892e-01 -3.45889278e-01  4.15061110e-01 -2.31614368e+00
#  -1.32357788e-01 -7.28251827e-02  5.48670181e-01  5.24731106e-01
#  -1.38323703e-02  2.58655012e-01  1.53440894e+00 -1.04369934e+00
#   5.97788309e-01 -1.37825499e+00 -1.05230132e+00  8.92742168e-01
#   8.31478571e-01  9.01661959e-02 -1.82517517e-01 -7.75289601e-01
#  -5.59457420e-01  2.13710294e-01  6.33039933e-01  6.81179207e-01
#  -8.95920256e-01 -4.70158498e-01  3.78451632e-01 -1.39117616e+00
#  -1.39720230e+00 -9.14981810e-01  3.99660748e-01  5.11940058e-01
#  -1.09500534e+00  1.49167062e+00  4.43617132e-01  5.95701756e-01
#  -1.24047779e+00 -2.68413756e-01 -5.49448218e-01 -1.82723724e+00
#   1.88826351e-01 -3.28633503e-01  3.45755282e-01 -2.11324166e+00
#   1.09678530e+00 -1.09715805e+00  6.71215623e-01  2.31966362e+00
#  -8.86732396e-01  6.76105593e-01  3.52892671e-01  1.17735776e+00
#  -1.03376474e+00  1.37963174e-02 -1.21596016e+00  8.51283606e-01
#   1.84582404e+00 -2.98818183e-01  1.44730061e-01  7.05397474e-01
#   9.25254268e-01 -3.70361025e-01 -1.51448668e-01  3.96203100e-01
#  -1.01156627e+00 -4.64721287e-01  6.15578803e-01  2.44748321e+00
#   5.67856090e-01 -1.00829987e+00 -9.28596651e-01  1.64738701e+00
#   8.36480478e-01 -2.21719522e-01  5.62672720e-01  5.77761388e-01
#  -1.93709412e+00  1.66052651e+00 -3.15112214e-01 -1.21906571e-01
#   7.75230288e-01  1.51869610e+00 -1.26105990e+00 -7.95405625e-01
#   1.10126822e+00 -2.79776528e+00 -2.15437953e+00  6.74455447e-01
#  -4.32175901e-01  2.89934920e+00 -1.93302058e-01  1.04857526e+00
#  -3.24618397e-01 -4.90604365e-01 -1.06156936e+00  1.28132821e+00
#   2.33621674e+00  3.17390122e-01  2.11013674e-01 -5.39950968e-01
#   1.63884336e+00 -2.65778149e-01 -9.27391667e-02 -1.15766069e+00
#   1.76293128e+00 -4.54674326e-01 -1.53394432e+00  4.70028519e-01
#   8.89502087e-01  6.57646480e-01  1.38067712e+00 -8.51480923e-01
#   1.37519163e+00 -5.73443680e-01  6.42098005e-01 -6.41877365e-01
#   4.33360153e-01 -1.11710882e-01  1.15610070e+00 -7.81305962e-01
#  -1.19600344e-01  9.11346436e-01  3.67403648e-01  8.58314156e-01
#  -1.80713342e-01 -9.60366681e-01 -1.09587258e+00 -7.16709745e-01
#  -2.52958705e+00  1.34541092e+00 -1.39731455e+00  2.83890943e-01
#   8.03047851e-01 -1.21512318e+00  6.27022657e-01  1.55130706e+00
#  -2.99336454e-02 -4.58455814e-02  6.05534842e-01 -2.16177625e-01
#  -2.56982109e+00 -3.07552393e-01  1.55000433e-01 -5.99669159e-01
#  -2.49815498e-02 -1.42820301e-01  1.12881953e+00 -7.98586735e-01
#   2.99815160e-01  1.55639576e+00 -1.14217660e+00 -1.45984747e-01
#  -5.20593361e-01 -5.05418134e-01  9.68089537e-02  5.84475143e-01
#  -6.47824016e-01 -9.13081015e-01  8.85412585e-01  3.83460056e-01
#   5.31009379e-01 -2.81927588e-01  2.13769653e-01  8.51088470e-01
#   8.50361436e-01 -1.00824698e+00 -1.54000004e+00 -2.77210011e-02
#  -1.49955859e+00 -1.56861462e+00  7.03896473e-01 -3.25051287e-01
#  -7.60392173e-01 -2.26415521e+00 -5.76293968e-01 -6.39911610e-01
#   3.04876173e+00  6.94875743e-01  2.12492522e-01  3.01628542e+00
#   7.78017202e-01 -7.49274513e-01 -1.31975835e+00  1.26962695e+00
#   4.79415667e-01 -8.53556940e-01  1.65458324e-01 -9.89248892e-01
#   8.07439380e-01 -1.26120088e+00  1.61888833e+00  4.25627743e-01
#  -1.58974024e+00  8.19553588e-01  6.15101104e-01  7.08002661e-01
#   4.92529127e-01  7.86791802e-01  9.50071323e-01 -1.98955128e-01
#  -4.92021864e-01  1.08600145e+00 -1.19088893e+00 -1.09381267e-01
#   7.95270340e-01 -8.08746005e-01  1.52612982e+00  1.91257016e+00
#  -1.41840999e+00  1.30661856e+00 -2.61873932e-01  2.91209006e-01
#   5.21743191e-01  4.69592132e-01 -2.82704840e-01 -4.22371087e-01
#  -2.39332465e-01 -1.28503250e-01 -1.66972852e+00  6.85198050e-01
#   7.63576716e-01 -2.31951601e+00  3.13346782e-01 -5.29305519e-01
#   4.20938857e-01 -1.88852001e+00  3.15684924e-01 -1.04895485e+00
#   1.00599214e+00  6.33296702e-01 -8.73200750e-01  6.96545473e-01
#  -1.34199811e+00  6.07537780e-01  1.82563004e+00 -1.01270849e-02
#   4.33895511e-01 -1.15453489e+00  4.50838894e-01  1.02466406e+00
#   1.59287703e+00  2.24686736e-01  1.29769103e+00  2.15397340e-01
#   6.21165507e-01 -8.44984990e-01 -2.18092624e+00 -1.25769320e+00
#   8.93477768e-01  6.29066471e-01 -6.35215128e-01 -3.13377625e-01
#  -1.29303583e-01 -7.25383004e-01 -1.89841786e-01 -1.57305755e+00
#  -2.87961367e-02 -7.26690631e-01 -3.43013496e-01 -1.09065224e-02
#  -8.60121078e-01  6.24188914e-01 -5.67336305e-01 -9.71268037e-02
#  -2.71621780e-01 -5.93970801e-01 -1.03927316e+00  5.40600610e-01
#   1.49871036e-01 -1.00817233e-01 -1.40742694e+00 -1.48222100e+00
#  -6.53107996e-01 -1.69603406e+00 -2.01507051e-01  1.10487983e+00
#   2.11009221e+00  1.66327594e+00  2.17530501e-01 -4.16062919e-01
#  -5.86459903e-01 -1.07456511e-01  6.72940893e-01 -2.16658326e-01
#  -1.13766105e+00 -1.32304133e+00 -2.88605746e-02  1.09793430e-02
#  -2.20559363e+00 -1.84947525e-01 -8.30178087e-01 -1.62357195e+00
#  -8.76113750e-01  1.21873422e-01  9.75813024e-02  3.78416832e-01
#  -8.45701331e-01 -1.39210800e+00 -1.16410631e+00  1.04408202e+00
#  -1.14163627e+00  6.25501728e-01  2.00794007e+00 -1.69448083e-01
#   4.64825036e-01  1.09806743e+00  2.48928156e+00 -1.16749861e+00
#   6.28618765e-01 -5.05982979e-01 -4.36844369e-01  3.24277376e-01
#   1.06123275e+00  1.80700898e+00 -4.56786265e-01  9.89836376e-01
#   6.44037230e-01  2.87156049e-01  3.74200718e-01 -6.45076802e-01
#   1.42812611e+00 -1.13682966e+00 -5.54441839e-01  4.79781669e-01
#  -1.84358127e-01  1.05313668e+00  1.45283286e+00 -9.64370372e-01
#  -2.03294288e+00 -2.04081581e+00 -5.66931593e-01  7.64573116e-01
#   9.07260154e-01  1.63536123e+00 -3.60277889e-01  1.66520335e+00
#   9.86505245e-01  1.25533883e-02  8.87724263e-01 -6.40796420e-01
#   4.80517997e-02 -8.16253679e-01 -2.18753905e-01 -9.25943870e-01
#   7.11166273e-01 -2.36304604e+00 -8.19635052e-01 -2.09570032e+00
#   1.52460201e+00  7.96862368e-02 -4.53668277e-01 -1.44903955e+00
#  -2.55543032e+00 -7.42242241e-01 -7.19085319e-01 -1.56963658e-02
#  -4.19414622e-01 -1.07502198e+00 -1.26227135e+00  5.70267034e-01
#  -8.65072189e-02  2.78949608e-01 -3.84562467e-01 -2.46680385e-01
#  -9.70108492e-01 -2.15168736e+00 -7.72119213e-01 -4.33949684e-01
#   8.39871201e-01  1.38670044e+00  3.06620443e-01  5.29013677e-01
#  -1.92587723e+00 -1.10293478e+00  2.99406201e-01 -2.84292891e+00
#  -3.73348564e-01 -6.92654707e-02 -1.01834952e+00  8.32904208e-01
#   9.36825376e-01  7.36241091e-01 -2.32748301e+00  6.07223029e-01
#  -3.73583421e-01  1.59422232e+00  4.65452392e-01 -9.88290257e-01
#  -9.38937645e-01  7.43060171e-01 -6.34852684e-01 -5.49611746e-01
#  -5.71797750e-02 -4.30981495e-01  5.78154299e-01 -2.02011870e-01
#   1.30140429e+00  1.29158669e+00  4.76115113e-01  3.47580012e-01
#   6.84933348e-01 -7.94743307e-01  5.68900002e-01  1.60905442e-01
#  -1.38707642e+00 -7.43965089e-01  4.25228250e-01 -1.38482252e+00
#   4.06566831e-01  1.71684860e+00 -1.13251716e+00  2.05293774e+00
#   1.74446280e-01 -4.09301015e-02  2.27822842e-01 -7.91549363e-01
#  -1.10076773e-01 -8.52979410e-01  1.62855488e+00 -4.23429881e-01
#  -1.12150589e+00  1.16684798e+00 -4.79055328e-01 -1.46112294e+00
#  -6.93744209e-01 -3.76670219e-01 -5.88824839e-02 -2.63972905e-02
#   7.41806622e-01 -1.57218852e-01 -2.63503646e-01  6.71673541e-01
#   9.49277542e-01 -9.28852204e-02 -1.45860854e+00  4.32182095e-01
#  -1.54142337e+00  2.28004938e-02  7.34561654e-01  8.11315205e-01
#   1.20775839e+00 -2.02004979e+00  1.01738627e+00  8.39918130e-02
#   5.35173661e-01  5.42168939e-01 -2.27420539e-01  1.85261789e-02
#   6.55338891e-01 -1.56909274e-01 -1.56113184e+00  1.21225582e+00
#  -6.02439558e-01 -2.38236018e-01 -9.09393289e-01 -1.01284372e+00
#  -5.51890555e-01 -9.12681434e-02 -2.03068841e-01  7.05380845e-01
#  -3.83947825e-01  4.65325244e-01  1.20731180e+00 -7.13140960e-02
#   1.17553632e+00  8.07171320e-01 -8.41321208e-01 -1.79270025e+00
#  -5.43768726e-01  8.83611643e-01  1.08351332e-01 -3.38332032e-01
#   1.50444637e+00  1.08787647e-01 -4.26308611e-01  1.86657042e-01
#   1.64016087e+00  3.29051606e-01  2.75233947e-01 -1.01851938e+00
#   1.17365360e+00 -3.69843539e-01 -3.06386720e-02  6.62521388e-01
#   2.07790440e-01 -1.02905040e+00  5.67009630e-01 -5.92294672e-01
#   8.56025323e-01  2.23438393e-02  1.47969134e+00 -3.56026814e-01
#   2.81694867e-01  1.83606855e+00  7.73976445e-01 -2.83603896e+00
#   3.09151398e-01 -4.88623611e-01 -3.63868759e-01 -4.85579705e-01
#   9.66498962e-01  4.56440003e-01  1.67518506e-01 -1.65945598e+00
#  -4.55907841e-01  3.49400408e-01  4.70884969e-01  1.55126254e+00
#   8.07178249e-01  6.27508440e-02 -4.87951909e-01  5.19014125e-01
#  -1.06224335e-01  6.22142449e-01 -3.75749963e-01 -1.35402726e+00
#   3.49711693e-01  2.17822264e+00  5.13966155e-01 -7.98602135e-01
#  -1.67667491e+00  1.04330869e-01  8.20661380e-01  4.93400235e-01
#   1.49584027e+00 -8.48330941e-01  5.58386888e-01  2.40543342e+00
#  -1.66636284e+00  5.36129807e-01  3.69616261e-01 -1.06825606e-01
#   1.67048116e+00  4.08455708e-01  2.75679559e-01  5.00607100e-01
#  -4.28136019e-01 -1.25891949e+00  1.40319573e+00  1.88519651e+00
#  -1.03645213e+00  1.33911002e+00  6.16836222e-01  5.49035451e-01
#   1.15499719e+00 -2.58771461e-01  9.01348073e-01 -5.38930746e-01
#  -1.94777454e-01  2.15219388e+00  1.13612314e+00  6.28131077e-01
#  -2.70814897e-01 -4.11837061e-01  1.17528024e+00  2.82272345e-01
#   2.21166729e+00  1.24713528e+00 -2.24433054e+00  5.07655928e-01
#  -4.11489075e-01 -1.44206437e-01  4.37368654e-01  5.78850864e-01
#   3.73009626e-01 -1.17541626e+00  6.82630266e-01  7.77108633e-02
#  -5.61489097e-01 -3.70094989e-01  1.11653561e+00  8.59006984e-02
#   2.42607226e-01 -1.69401277e+00 -5.85244060e-02 -8.40781585e-01
#   8.17199428e-01 -5.87856655e-01 -8.00515704e-01 -9.85269450e-01
#   1.42977188e+00  1.96071873e+00 -1.24056680e+00  1.48346976e-01
#   3.28539144e-01  1.15747060e-01  1.26104392e+00  1.29101490e+00
#   1.05518559e+00  7.29566933e-01  5.06438039e-01  9.53423545e-01
#  -2.21158268e-01  1.59092072e+00  1.27729964e+00 -1.45229910e-02
#   2.34393222e-01  1.73942617e+00  1.31072035e-01  1.46846460e+00
#  -5.03225194e-01 -1.59919453e+00  1.88173394e+00  2.15681950e-01
#   7.35543572e-01  1.20445880e-01  7.50047451e-01  8.28668928e-01
#  -7.60340928e-03  6.17841085e-01 -7.65565328e-01 -3.39660661e-01
#  -4.90337292e-01 -7.65422380e-01 -3.96911566e-01 -1.30087855e+00
#   2.33086433e-01  1.20644404e+00  6.62185880e-01 -1.70823791e-01
#  -2.91924924e+00 -6.02318588e-01 -2.27125854e+00  5.21005545e-01
#   5.07595626e-01  1.74287516e-02 -3.58044893e-01  6.38451551e-01
#   2.21872854e+00  8.01880642e-01  2.20011314e+00  1.22705110e+00
#  -1.06242379e+00  5.01886688e-01  1.04369717e+00  8.06685696e-01
#  -2.65089694e-01 -4.85338612e-01  8.28843842e-01  6.42578840e-01
#   4.13487491e-01  8.14960923e-01 -1.19238296e+00  9.25292910e-01
#   2.00122015e-01  1.39915413e+00  4.76077945e-01 -1.00394428e+00
#  -8.41121429e-01 -1.84838412e-01 -7.50510482e-01 -4.65331697e-01
#  -2.75214375e-01  6.25008553e-01  9.42829552e-01 -7.48205380e-02
#  -3.16228407e-03  1.26042997e+00 -8.50895013e-01  4.18644910e-01
#   1.21191191e+00 -2.55982748e-01 -8.91585292e-01 -3.44915793e-01
#   1.51635456e+00  2.51183376e-01 -1.21353994e+00  2.09448576e+00
#  -1.60637470e+00  2.35070581e+00  3.22387151e-01 -1.78831542e-01
#  -5.27301233e-01 -6.68966636e-01  1.06993569e+00 -1.51886892e+00
#   9.91401976e-01 -1.09721798e-01  5.38555032e-02  1.08279664e-01
#  -1.20119228e+00  1.57514029e+00  1.94457407e-01 -1.70723884e+00
#  -1.41045398e+00  8.26936501e-01  1.33903118e+00  1.72184795e+00
#  -1.38362867e-01  4.25375236e+00 -4.70030121e-01 -1.27155355e+00
#  -1.11108756e+00  4.55460248e-01 -1.34435045e+00  2.34847800e-01
#   4.63573627e-01 -2.17960371e+00 -5.79872581e-01 -8.33227120e-01
#   9.89409679e-01 -3.93676079e-01 -6.45304846e-01 -3.54800740e-01
#  -4.95875018e-01  2.16948604e+00 -2.32037135e+00 -3.70363500e-01
#  -1.12721213e+00 -6.01793599e-02 -8.95091411e-01 -1.77915064e+00
#  -2.56787456e-01 -9.30465433e-01 -1.98097071e+00  8.61302455e-01
#   3.82325708e-02 -9.23489892e-01 -2.54601780e-01 -1.41983821e+00
#   2.43510962e-01  8.05374440e-01  1.76924277e+00  1.20882089e+00
#  -2.30289960e+00  2.41910195e-01  2.08859461e+00  3.79882860e-01
#  -1.17739315e+00 -1.29848970e-01  5.06562180e-01  4.66404443e-01
#  -8.59491384e-01 -3.72991094e-01  3.27666130e-01 -3.31630413e-01
#   7.80526339e-01 -9.42722367e-01 -2.75050653e-01  7.51424093e-01
#  -2.11081614e-01  7.03499023e-02  9.50759746e-01  1.93402976e+00
#   2.76418809e-01 -1.03958946e-02  1.38224496e+00 -5.19560415e-01
#   4.47766061e-01 -2.20302888e-01  5.25920741e-01 -9.03005076e-01
#   1.35135161e+00  1.36688786e+00  1.49720708e-01  7.11286065e-01
#   3.04659711e-01 -8.42164708e-01  9.45857874e-01  1.22124095e+00
#   5.04576436e-01 -1.27094325e-01 -7.12862490e-01 -1.37909637e-01
#  -1.20232242e+00 -4.17953588e-01 -3.39368895e+00 -4.25412745e-01
#  -6.19553372e-01  7.04057138e-01 -1.72026179e+00 -4.33776123e-01
#   5.95992036e-01 -9.78089438e-02 -2.94726662e-01  3.82992988e-01
#   1.94498175e+00  3.69812284e-01 -1.72149960e+00  6.25837618e-01
#   7.49928444e-02  1.69735746e+00 -1.02760338e+00  5.70402140e-01
#  -6.06426924e-01 -1.89019149e+00 -1.09656458e+00 -1.25105392e+00
#  -2.57752427e+00 -3.78893410e-01 -1.85961216e+00 -1.10857969e+00
#  -1.49056040e-01  3.86990374e-01 -2.12225993e+00  6.43357424e-01
#   2.66089950e-01 -5.76665612e-01  1.87552454e-01  2.58300429e-01
#  -4.43876370e-01  1.35892317e+00  1.74530693e+00  1.32141755e+00
#   3.44557373e-01  4.26433235e-01  1.83827629e-01 -1.27897541e+00
#   9.56448437e-01  8.98211275e-03  1.05801100e+00 -8.05528380e-01
#  -1.40482592e+00  9.34982807e-01 -1.59128504e+00 -1.30401704e+00
#  -1.66482220e-01  5.79522364e-01 -1.37832438e+00  1.13670650e+00
#  -6.87800368e-01 -3.74628526e-01 -1.85330788e+00  1.67231512e-02
#   5.83524736e-01  4.01753973e-01  3.55787772e-01  3.44402426e-01
#   7.30579574e-01  6.34436399e-01 -2.14915794e+00  3.38910464e-01
#  -1.59287096e+00 -2.28157912e-01  5.03433985e-01  8.99590499e-01
#   7.10265448e-01 -2.64594506e-01  2.65244081e-01  4.78950848e-01
#   1.08452389e+00 -1.29169595e+00  4.20357450e-01  1.72260393e-01
#  -8.19472544e-01  2.16521739e+00 -1.11075251e+00 -2.48847580e-01
#  -1.33291189e+00 -1.52945541e-01  3.52342035e-01 -1.10833780e-01
#   1.19159639e-01 -1.37311472e-01  8.21141193e-01  1.18801974e-01]
# (array([  5.,  33., 104., 218., 282., 239.,  93.,  21.,   3.,   2.]),
#  array([-3.39368895, -2.62894482, -1.86420069, -1.09945656, -0.33471243,
#          0.4300317 ,  1.19477584,  1.95951997,  2.7242641 ,  3.48900823,
#          4.25375236]),
#  <BarContainer object of 10 artists>)

# %%
## T Distribution using scipy stats
from scipy.stats import t
#T_Dist = t.rvs(df = 10,  size=1000) #df - no. of independent observations in a set of data, degree of freedom
T_D = np.random.standard_t(10, size=1000) ##1st argument is dof, 2nd is sample size
print("samples from T Distribution using scipy stats library are: ", T_D)
pyplot.hist(T_D,color='purple')
# Out:
# samples from T Distribution using scipy stats library are:  [ 1.66632254e-01  9.05501978e-01  1.11760037e+00  3.00019580e+00
#   6.52767979e-01  1.00194394e+00 -1.75287819e-01  5.26760135e-01
#   7.26648356e-01  1.25265368e-02  3.96655115e-01 -3.56976916e-01
#  -1.31801275e+00 -2.91070201e-01  4.78709542e-01  8.15632275e-01
#   4.65923473e-01  2.25486706e-01  2.58137342e-01  1.42946424e+00
#   5.77687504e-01 -4.82275655e-02 -1.07728133e+00  1.06812607e-01
#  -1.98778106e+00  4.16392973e-01  9.04245651e-01 -1.75952782e+00
#  -5.00582385e-01 -3.08023115e-01 -1.79321658e+00  3.35693742e+00
#  -1.70592134e+00  3.80097602e-01  3.18359622e+00 -2.01991823e-01
#  -5.05718587e-01  4.50890536e-02  9.35022177e-04 -8.59107584e-02
#  -5.02544912e-01 -8.41531604e-01  1.24090086e+00 -3.51224944e-01
#   1.21004127e+00 -1.09655945e-01 -7.90775053e-02  1.58919220e+00
#   9.65289088e-01  1.39336103e+00  3.38575936e+00 -4.66268279e-01
#  -2.37324221e-01  1.14469276e+00  8.11927435e-01 -1.11273410e+00
#  -1.70316197e+00 -2.36461738e-01  9.40830712e-01  3.46891590e-01
#   7.81089730e-01  2.65935155e-02  6.65784404e-01 -6.38053404e-01
#  -2.95012721e-01  2.33979757e-01  6.57128118e-02  1.63957945e+00
#   1.46026014e+00 -2.50511410e-01 -1.15023986e+00  3.85607331e-01
#  -8.77509670e-01  4.47396659e-01  2.66218908e-01  1.31831834e+00
#   1.13537313e+00  1.17357354e-01  6.44451931e-01  4.59516886e-01
#  -3.96305164e-01  1.82678168e+00  4.24533906e-01  3.06637672e-01
#   8.06398438e-01  1.54587720e+00 -6.52560832e-01 -1.24932891e-01
#   3.19245172e-01 -1.43158651e+00 -1.34956278e-02 -1.48420657e-01
#   4.83976089e-01 -6.01587155e-01  2.33548503e+00  1.57384949e+00
#  -3.46096502e-01  3.89690347e-01 -2.25704002e-01  1.92060923e+00
#   1.21474378e+00  1.30294510e+00  4.02797423e-01 -2.12640408e+00
#   8.70568840e-01  7.50744916e-01  2.88772156e-01 -2.47465101e+00
#  -1.44515583e-01 -3.89555464e-01 -4.91313945e-01  5.33163432e-01
#   9.11734315e-01 -2.80211797e-01  2.34865457e-01 -1.38737878e+00
#  -9.83908397e-01 -1.68458710e-01 -2.15662569e+00  7.21662959e-01
#   1.67700966e+00  1.22727465e+00 -1.74592730e-01  7.23762142e-01
#   1.80161029e+00 -3.01367270e-01 -4.11856923e-01  1.92605292e-01
#   8.97187994e-01 -4.34122436e-01 -3.43672768e-01 -5.17453202e-01
#  -1.29347285e+00 -1.74642246e+00  9.30801478e-01  7.12345407e-01
#   1.35409894e+00 -9.22318087e-01  7.41809893e-01 -6.50426483e-01
#  -1.72444561e+00 -1.13114889e+00  1.14990901e+00 -2.56597602e+00
#   1.01591084e-01  4.92622470e-01 -1.72238475e+00  1.39228608e+00
#   1.00770715e+00  1.09727583e-01  1.08913187e+00  1.13708059e+00
#   1.96257367e+00 -7.60950150e-01 -7.83125783e-01 -8.24141662e-01
#  -1.45332450e+00 -2.35813986e-01  2.53693672e-01  8.22089252e-01
#  -8.03751411e-01 -1.38667138e-01  3.36419489e-01 -8.28618212e-02
#   3.91081506e-01 -2.31622599e+00 -1.02462206e+00 -9.41289352e-01
#   1.89036120e+00 -3.97369042e-01 -9.86251398e-02  6.54999937e-01
#  -1.30570233e+00 -6.03860499e-01  4.85962141e-01 -2.97298292e-01
#  -8.74925387e-01  9.69586411e-01  1.47827968e+00  1.54185312e+00
#   4.04940936e-02 -1.37378357e+00 -1.32877083e+00 -6.74785279e-01
#   1.39529059e-01  1.92011710e-01 -4.11609253e-01  7.53803728e-01
#   1.69298061e-01  7.40375541e-01 -6.84065841e-01 -7.76024506e-01
#   1.18943651e+00  2.61042877e+00 -8.23896290e-01 -2.87208575e+00
#   2.48855566e-01  1.00431309e+00 -2.56538312e-01  6.49762218e-01
#  -1.24157871e+00 -5.81185139e-01 -3.70931990e-01 -2.04580454e+00
#   2.24301553e-01  7.84968159e-01 -1.61669479e-01  1.42071938e+00
#  -1.21731472e+00  3.67724174e-01  1.09209535e-01 -1.90343816e+00
#   5.25576471e-01 -4.11511193e+00 -1.96593052e+00  3.65943185e-01
#  -1.75426681e-01 -3.36459853e-02  4.63000741e-01 -1.25769887e-01
#  -9.62234424e-01  3.06524323e-02  6.76707590e-02 -1.95347488e-02
#   2.61513498e-01  1.05013489e+00  4.52149733e-01 -2.00171403e+00
#   1.32470113e+00 -8.51387475e-02  2.17096829e-01  2.59445935e-01
#  -4.17748709e-01  2.24077227e+00 -5.71432759e-01 -7.25372854e-02
#   5.44127041e-02 -8.44762426e-01  5.79191344e-01 -1.70272842e+00
#  -4.52249488e+00  6.61388702e-01 -1.18236943e-01 -9.20838933e-01
#   7.99211313e-01  1.36236735e-01  2.01012942e+00 -1.97616726e+00
#   2.41483097e+00 -7.96995127e-01  4.57180363e-01  2.25722965e-02
#   7.56907681e-01 -1.89507592e+00 -2.54457933e-01 -2.51389383e-01
#  -3.22558800e-01  1.22244441e+00  8.00958020e-02  1.24820809e+00
#  -2.30936089e+00 -8.41830165e-01 -3.56005315e-01 -2.01176458e-01
#  -8.71784626e-01  9.95891560e-02  4.00665577e-01  1.75927807e+00
#  -7.96755471e-01 -9.69169442e-01  1.14260380e+00 -1.20938207e+00
#  -1.20069061e+00 -8.84129354e-01 -3.01117841e+00  9.01791732e-01
#  -1.81237630e+00  4.26963532e-01 -7.46477116e-01 -8.02583382e-01
#   7.24572848e-01  1.12378867e+00 -1.18707320e-01 -3.69165843e-01
#   3.19359242e-01  1.50192355e+00  6.34685407e-01  2.14472604e+00
#  -6.59603132e-01  4.03088208e-01 -4.68712146e-01 -5.99990512e-01
#  -4.41812451e-01 -2.04347871e+00  1.89775496e-02 -5.02996957e-01
#  -9.50184169e-01  3.56326688e-01  9.43593800e-01 -1.42641890e+00
#   2.42993940e+00  2.13652121e+00  1.21201222e-01 -1.35221487e+00
#   1.20971584e+00 -1.14969159e+00  1.30577027e+00 -2.19190455e-01
#  -2.31753421e+00  2.34470628e-01  2.32952799e+00 -3.88812025e-01
#   2.65896189e-01 -1.02868283e+00 -8.81820210e-01 -1.50316732e+00
#  -1.08876348e+00  1.05876373e-01  1.64143703e+00 -1.37733507e+00
#  -1.63774107e+00  1.77647133e+00 -1.52266255e+00 -8.44858744e-01
#  -4.83872339e+00 -1.13811314e+00  9.42209308e-01 -8.89860537e-01
#  -6.84405108e-01 -5.56428944e-02 -5.80127529e-01  1.24994679e+00
#   8.67715858e-01  9.22485442e-01  7.09409470e-01 -1.68322022e+00
#  -1.68068092e+00 -1.09526832e+00  5.79741827e-01 -7.78942698e-01
#  -1.63378154e+00  4.57126050e-02  1.46164536e+00 -1.36653644e+00
#  -1.75409408e+00  4.42891132e-02 -4.96539311e-01 -6.83343566e-01
#  -1.12173837e-01  2.06427959e+00  2.02724449e+00  9.23129195e-03
#   1.40760861e+00 -6.29647193e-01 -2.48274874e-01  5.12509934e-01
#   3.42536380e-01 -5.33944484e-01 -1.90947777e+00 -2.32445563e-02
#   4.40731610e-01 -1.83730774e-01  8.84367820e-01  5.28318048e-01
#   2.08287685e-01  3.92097010e-01  1.53286489e+00  1.71902218e+00
#   9.49187507e-01  4.61841379e-01  5.50120305e-01  1.76479451e-01
#   2.24047321e+00  9.29113289e-01  1.79707043e+00 -3.90358738e-01
#   4.22754810e-01 -4.88701015e-01  1.39583826e+00  6.72705869e-02
#   7.45697544e-01  2.24965287e-01 -1.69708154e+00  1.02680712e-01
#  -2.44081244e-01  1.30804194e+00 -1.21078637e+00 -3.94641948e-01
#  -4.40710538e-01 -6.87398717e-01  4.12933051e-01 -1.47384961e+00
#  -2.75070898e-01  9.82485134e-01  1.57463511e+00 -3.03017172e-01
#  -1.08716020e+00 -4.81790555e-01  1.14572636e+00  1.33469751e+00
#  -4.52563878e-01  1.62836969e-01  6.68635204e-02  4.49453338e-01
#   8.94721520e-02  3.12271577e+00  8.68246858e-01 -3.03337667e+00
#  -1.43358671e+00 -1.03253081e+00  7.51114424e-01  1.82416554e+00
#   1.51342389e-01  1.69740702e+00 -9.62026565e-01  1.39202713e+00
#  -1.57844788e-01 -1.03364819e+00 -4.28775394e-01 -7.94117291e-01
#  -1.82279697e+00 -4.16554772e-01 -1.88267248e+00 -1.08271570e+00
#  -3.32537702e-01 -2.90716349e-01  7.46528576e-02 -1.85646948e+00
#   1.13346753e+00 -2.46516023e-01  7.98748676e-01  9.45390237e-01
#   7.87795175e-01  2.29416130e+00  1.94550886e+00 -3.68518974e-01
#  -7.86535662e-01 -1.03893178e+00 -2.91252466e-01 -1.08031570e-01
#  -4.36460952e-01 -1.06645806e+00  1.39478573e+00 -1.78627564e-01
#  -7.01321220e-01  5.66032832e-01 -9.80136677e-01 -1.39977182e+00
#  -2.33150414e-01 -4.60590718e-01  1.24413621e+00 -5.51861391e-01
#  -1.84230001e+00 -5.59972226e-01  1.01721620e+00 -1.67710508e+00
#   3.39252552e-01 -2.42552122e+00  9.26621752e-01  1.70594571e-01
#  -1.60228254e+00  6.77185140e-01  2.57029853e+00  1.05085626e-01
#  -6.81958936e-01 -2.09222456e-01  6.87939580e-01 -4.78079861e-01
#  -8.45199006e-01  1.08528336e+00  1.37932206e+00  7.54036005e-01
#  -2.79281529e-01 -1.33869778e+00 -3.20002806e+00 -6.94637620e-01
#   2.67361865e+00 -1.73032846e-01 -1.40982893e-01  4.82291244e-01
#   9.42516917e-01  1.45670442e+00  8.22577668e-01  9.76543131e-01
#  -1.43500152e+00 -2.04384213e-01 -4.05453322e-01  6.74760973e-01
#  -1.33119280e+00 -9.81888783e-01  3.61073816e+00  6.61219349e-01
#   2.27445768e+00  1.19378897e+00  6.58367035e-01  7.33938638e-01
#  -3.19590107e-01 -5.09317607e-01  1.05523099e+00 -7.70277342e-02
#  -1.40415335e+00 -1.03437475e+00 -9.19409983e-02  9.49962225e-01
#  -2.35938137e-01  9.35331482e-01  9.12206815e-01 -8.60708503e-01
#  -1.09651240e+00  5.37174450e-01 -1.11129798e-01 -1.71330098e+00
#  -5.56107226e-02 -1.99480754e-01  5.27268800e-01 -4.86334609e-01
#   6.14855070e-01  1.26755651e-02  8.98424230e-01  7.00537651e-01
#   5.82859079e-01 -1.20227408e-01 -7.36978336e-01 -1.23886129e+00
#   1.46674584e+00 -2.05854829e-01  8.25756385e-01  7.78545273e-01
#   1.23656268e+00 -6.12269232e-01  1.53166088e+00 -1.12430191e+00
#   1.89805335e+00  7.01064309e-02  1.69951745e+00  2.76184120e-01
#   6.10805866e-01 -1.73752666e+00 -9.10168849e-01  9.77560666e-02
#   2.89930719e+00  1.05021080e-01  5.81088016e-01 -7.35026475e-01
#  -1.08967685e+00  4.62191826e-01 -1.08766737e+00 -1.59079348e+00
#   6.77842178e-01 -1.48455321e+00 -5.71276482e-01 -2.33525881e+00
#  -1.75332258e-01  1.54217032e-01 -2.56041233e-01  2.20550747e+00
#   1.70341393e+00 -7.01644652e-01  1.04386787e+00  3.41429544e+00
#   9.79144154e-02 -2.28580255e+00  1.06353438e+00 -1.05022361e+00
#  -3.71521920e-01  1.48512427e+00 -2.39145880e+00 -6.26991047e-01
#   4.76986017e-01  1.90245694e+00 -2.03921357e-02  1.41678907e-01
#  -9.82041226e-01  2.16456414e+00 -1.19684581e+00 -7.00808616e-01
#  -3.57478154e-01 -6.83385066e-01  7.87784535e-03  6.29716605e-01
#  -4.29541618e-01 -5.92489032e-01  1.14148726e+00 -1.16119343e+00
#  -2.23252031e+00 -2.12714326e-01  7.08561170e-02 -5.69483568e-01
#   5.18084601e-01 -5.72156230e-01 -5.66707050e-01 -2.14336686e+00
#   9.56174599e-01 -1.00922026e+00  5.48976709e-01  1.01551233e+00
#  -3.10077733e-01 -4.69987520e-01 -8.84517932e-01 -1.19454542e+00
#  -9.33612473e-01 -8.50475437e-01 -7.86741605e-02 -6.74708987e-01
#  -1.27828686e+00 -9.07713798e-01  3.11879845e-01 -2.69665045e+00
#   9.16086289e-01  2.23890157e-01 -2.46969091e+00 -1.29517761e+00
#  -3.00206326e-01  8.39486644e-01  1.64830743e+00 -1.47078386e+00
#  -6.53180371e-01 -4.47186330e-01 -7.72992608e-01  5.84480734e-01
#  -6.92151867e-01 -9.52280011e-01 -2.40341364e-01  9.04715066e-01
#   1.01831726e+00  6.99314344e-01 -5.77135328e-01 -2.44933557e-03
#   1.37458611e+00  5.76294288e-01 -1.28659420e+00  6.50603170e-01
#  -4.52089633e-01 -3.16011560e-01  1.28997123e+00 -2.82776569e-01
#  -6.89290267e-01 -4.60482519e-01 -6.49309987e-01  6.48244393e-01
#   7.92008303e-01 -1.76596386e-01 -1.41729986e+00 -9.77791716e-01
#  -3.43014396e-01 -1.29369290e+00 -5.87940426e-01 -2.04601011e+00
#  -3.33720568e-01  9.15726739e-01  1.23616796e-01  3.95560239e-01
#   7.64951319e-01  7.50019690e-01 -4.40755006e-01  2.25684717e-01
#   3.58499637e-01  4.27341340e-02  2.40500059e+00 -7.99436309e-01
#  -4.22591838e+00  6.92776373e-01  1.01077358e+00  8.04062389e-01
#   5.77284483e-01  1.56903110e+00  1.11006776e+00 -9.80249933e-01
#  -1.97072863e-01  4.81139296e-01 -1.02980579e+00 -2.69987296e-01
#   1.43884066e+00 -6.99109676e-02  7.16837441e-01 -1.05638871e+00
#  -2.29439604e-01 -2.02539349e+00 -1.26216945e+00 -1.73250310e+00
#  -1.62577170e-01  2.96465022e-01  1.07343031e+00 -1.28548987e-01
#  -7.08098584e-01 -3.04649993e-01 -3.54468205e-02  1.76308045e+00
#  -1.58393110e+00 -3.92000875e-01  1.26007075e+00 -7.19084325e-01
#   1.72026425e+00 -9.87448208e-01 -1.26358173e+00 -3.84618846e-01
#  -2.22373164e-01  6.72399708e-01 -3.04785748e-01 -1.08902748e+00
#  -1.19397531e+00 -9.75689095e-01  2.68249242e+00 -3.66977521e+00
#  -2.32508387e-01 -9.81764374e-01 -7.22304864e-01 -1.55713560e-01
#   1.98461024e+00  1.09014326e+00 -5.75649226e-01  1.40684750e+00
#  -6.42849215e-01  5.07136833e-01 -1.65038035e+00 -1.08116680e+00
#   1.39446783e-01  2.32318596e+00 -7.79641073e-01  8.29674630e-01
#  -5.90545669e-01 -1.22011613e+00  3.02384722e+00  1.03577702e+00
#   4.70760360e-01 -4.11578724e+00  8.47639181e-01  2.01916118e+00
#  -2.31261406e+00  2.37288927e+00  8.39670083e-02  5.41777060e-01
#  -5.72899280e-02  5.85183218e-01  7.38812032e-01  3.54573985e-01
#   4.93169597e-01  5.08225233e-01 -1.19860479e+00 -3.60132095e-01
#  -7.19031516e-01  5.58599614e-01 -5.43512523e-03 -1.07072909e+00
#   3.53063800e-01 -1.54399635e+00 -1.82080971e+00  1.18910429e-01
#   2.28150680e-01  1.81298469e-01 -1.18187064e-01 -1.44187847e+00
#  -1.28186118e+00 -1.39180381e+00 -9.56553383e-01 -1.39156616e+00
#  -1.37175921e+00  1.09856841e+00 -2.55758852e+00 -1.50616986e+00
#  -6.05967459e-01 -1.38017816e+00  1.78774131e+00  8.35767502e-01
#  -8.89489410e-01  1.98997136e-01  1.44074327e+00 -8.18553834e-01
#  -1.26522058e+00  5.99659876e-01  1.20191378e+00  4.78069911e-01
#   3.62045358e-01 -4.73166580e-01  1.09078215e+00 -8.45788403e-01
#   1.13870262e-01 -1.03079163e+00  1.01063561e-01  1.91896469e+00
#   6.69258409e-01  7.52215995e-01 -1.71101852e+00 -1.38437350e+00
#   3.56718510e-01 -1.09773167e+00  2.41823374e+00  4.75387549e-01
#   1.23655451e+00  1.33345460e+00 -4.01236184e-01 -1.71507933e-01
#  -1.99816779e+00 -8.44209798e-01 -5.20246084e-01 -4.51835003e-01
#  -3.65072515e+00  2.53966518e-01  3.53173660e-02 -3.38879861e-01
#  -2.93385167e-01 -1.20796161e+00 -7.63954439e-01  1.37636342e+00
#   2.45564285e+00 -1.19789986e+00  9.10355079e-01 -9.43297657e-01
#  -1.41450362e+00  1.16361805e-01 -1.05579496e+00  5.58255186e-01
#   3.86569157e-01 -7.34585027e-01 -1.77033138e+00  8.11866029e-01
#   9.93060645e-02 -1.23366144e+00 -3.89689918e-01 -2.42720391e-01
#  -4.31760301e-01  2.03264359e+00 -1.48779687e+00  1.38415141e-01
#  -4.51812311e-01  9.28522845e-01 -2.57665997e-01  7.60715368e-02
#   1.53605750e-01  1.21100374e+00 -1.42915079e+00 -1.06061612e+00
#  -2.80179547e-01 -2.94055136e-01  2.20571035e-01 -2.89259458e-01
#  -6.05851152e-01 -9.29563295e-01 -9.10095247e-01 -5.97141214e-02
#   6.57499286e-01 -1.47060948e-01  1.70851692e+00  8.23704906e-01
#  -5.90068412e-01 -8.45528711e-01 -1.43235403e+00  5.70910560e-02
#  -1.28932044e-01 -6.81934366e-01  3.58721977e+00 -4.19466177e-01
#  -2.93882882e-01  5.62251481e-01 -1.28406820e+00 -4.91211872e-01
#  -1.05886345e+00  1.23842226e+00 -1.87336007e+00  1.74132812e-01
#  -7.69835340e-01 -1.37889209e+00 -1.19753087e+00 -2.63586845e+00
#   8.45620876e-01  6.44048461e-01 -3.14357231e-01  2.76412504e+00
#  -7.45823306e-01 -2.31681517e-01 -1.59908819e+00 -9.93022267e-01
#  -5.07470791e-01 -2.75664591e-01 -5.44597350e-01 -4.48559030e-01
#  -5.39299008e-02 -3.78114190e-01 -3.16126171e-01 -2.07155563e+00
#  -4.98213028e-02 -1.56903584e+00 -6.29682502e-01  7.08686933e-02
#   7.46865651e-01  9.83661116e-01 -1.06852834e+00 -1.33912878e+00
#   1.75254388e+00 -3.89068621e-01  1.17457616e+00  2.28437873e-01
#  -6.70009215e-01  5.65029524e-01  5.28897337e-01  2.67664714e-01
#  -1.24835364e-01 -3.15428468e+00  1.63972708e+00  2.78922694e-01
#  -3.06270258e-01  3.33249500e-01  1.49751631e+00  1.64188614e+00
#  -1.61553191e+00 -7.71400904e-01  4.64320774e-01 -2.85583246e-01
#   8.40214835e-01 -1.65289702e+00  1.67903137e+00 -7.27315343e-01
#   1.14940092e+00 -2.62427007e-01 -1.55657089e+00 -4.25225763e-01
#   7.29078271e-02 -7.43921333e-01 -3.56510103e-01  4.12932088e-01
#  -2.46877470e+00  2.61553828e-01 -3.41285768e-01  3.57623249e-01
#   1.14567721e+00 -3.12499456e-01 -2.29120710e+00  3.91784772e-01
#  -3.84529332e-02 -7.42920995e-02  1.11456726e-01 -3.82694654e-01
#   1.75142192e+00  6.06281949e-01  9.41258850e-01 -3.72661448e-01
#   7.10226338e-01  7.95492300e-01 -9.02736985e-02  3.06227598e-01
#  -1.99132491e+00 -3.27901628e-01  5.57662473e-01 -2.27655402e+00
#   4.18967788e-01 -9.40528633e-01 -5.96575116e-01 -9.93930580e-01
#  -3.20612470e-01  4.50991732e-01  5.39430208e+00  1.45340620e+00
#   1.33959821e+00 -5.35599526e-01  6.80169277e-01 -5.70738356e-01
#  -3.25786268e-01  4.35001366e-01  9.00060524e-01 -2.05770888e-01
#  -8.40581325e-01 -2.05479805e+00  6.10663372e-01 -6.75094993e-01
#   8.73135241e-01 -1.99389934e+00  8.21109656e-01 -8.90674044e-01
#   9.06289025e-01 -2.32241307e-02 -5.97312444e-01  6.22307024e-01
#   3.85601303e-01 -4.26511431e-01  8.80035673e-02  5.63561787e-01
#   7.40387858e-01 -9.28676480e-01 -1.10166303e-01 -1.47694481e+00
#  -8.14620219e-01 -2.94944848e-01 -6.51121557e-01  6.23656513e-01
#  -1.68625684e-02  1.94087999e-02 -7.50870003e-01  6.17197993e-01
#   6.27325527e-01 -1.90499232e+00 -7.81770895e-02  4.59537046e-01
#  -2.16360423e+00 -3.05829671e-01 -3.72250979e-01  2.83851346e-01
#  -8.13555930e-01 -9.61253434e-02  1.52939324e+00 -6.32534024e-01]
# (array([  5.,   7.,  48., 197., 367., 266.,  86.,  18.,   5.,   1.]),
#  array([-4.83872339, -3.81542085, -2.7921183 , -1.76881575, -0.74551321,
#          0.27778934,  1.30109189,  2.32439444,  3.34769698,  4.37099953,
#          5.39430208]),
#  <BarContainer object of 10 artists>)

# %%
##F distribution using scipy library
from scipy.stats import f
#F_Dist = f.rvs(dfn=10, dfd=20,loc=0, scale=1, size=1000) # dfn, dof for numertaor
## F Distribution  ---numpy.random.f(dfnum, dfden, size=None), dfnum = dof in numerator
#Draw samples from an F distribution.
F_Dist = np.random.f(dfnum = 3, dfden = 2, size=100) # using numpy library
#print("samples from F Distribution using scipy stats library are: ", F_Dist)
pyplot.hist(F_Dist,color='purple')
# Out:
# (array([78.,  7.,  7.,  5.,  2.,  0.,  0.,  0.,  0.,  1.]),
#  array([1.96467527e-02, 2.83919285e+00, 5.65873896e+00, 8.47828506e+00,
#         1.12978312e+01, 1.41173773e+01, 1.69369234e+01, 1.97564695e+01,
#         2.25760156e+01, 2.53955617e+01, 2.82151078e+01]),
#  <BarContainer object of 10 artists>)

# %%
##Gamma Distribution
Gamma_D = np.random.gamma(shape=2, scale = 1, size = 1000) # shape is mean, scale is width
print("samples from Gamma Distribution are: ", Gamma_D)
pyplot.hist(Gamma_D,color='purple')
# Out:
# samples from Gamma Distribution are:  [ 0.78765308  6.02159488  0.29886114  3.06435267  2.05828336  4.74727089
#   3.38458958  2.33585623  2.43954045  0.47969906  4.00601579  0.69374295
#   0.73007455  4.30829978  3.17988136  1.31824917  1.94765629  2.84265916
#   1.49006598  0.62568608  1.38500356  0.89764102  1.21531502  2.86691121
#   5.20147419  2.66501024  1.07710553  3.05606213  0.44741307  0.55698461
#   1.66857997  0.59905731  1.72575166  1.60214548  3.43520887  1.01239138
#   2.97087512  1.16974878  2.13011507  0.44995928  1.14468029  1.086899
#   0.77125772  1.95839027  1.04420508  2.56676976  2.30162736  1.41871357
#   0.36550236  3.84172143  1.11951598  1.16375062  1.64482039  1.573963
#   1.07520916  1.68279499  4.87986851  1.26303393  3.82455653  1.24239654
#   1.31014085  4.87624039  1.54549714  1.66166733  0.90499129  2.56153509
#   3.45816159  3.15423868  2.91905275  1.45005798  1.74959479  2.84096874
#   1.09724281  3.90386797  4.41509304  1.54699332  2.54897331  1.0618651
#   0.67711818  0.25700097  2.91552953  0.99446016  0.73594421  0.3274718
#   3.54443835  5.20135534  2.41080398  1.27128066  0.44469779  1.4905367
#   0.45173265  2.76308839  2.11566057  2.90940388  3.22129024  3.84541954
#   0.66303297  0.52387931  0.65807258  3.33252883  6.27899401  2.0774414
#   0.73943262  2.58665051  0.89455644  2.67427907  4.19962906  2.22244607
#   0.96988651  3.65089737  0.83128014  0.62649615  2.01246656  1.72564409
#   0.88743311  1.01734727  0.49876888  0.71711536  1.76310862  0.94599434
#   0.48478541  1.11472376  6.22377747  4.38549334  0.71645706  3.97954096
#   0.80940263  2.30932652  7.16941564  3.79282691  0.70735747  1.35962501
#   0.83794319  0.60272265  0.16017224  0.4527333   1.377233    1.58741128
#   1.84369047  4.68904924  0.93658511  1.62908521  3.40262969  0.88218365
#   1.93187305  4.43531562  2.33051177  0.87641337  1.10501752  1.24502853
#   3.84946583  5.6457054   2.04523847  0.35025649  2.00184485  1.73465541
#   2.6199263   1.48273815  0.98637943  4.70511965  0.30278917  2.03766061
#   3.19324684  2.374182    2.51394868  3.85676939  2.15084146  0.30186222
#   2.36876608  1.18320752  0.44981745  0.80911454  1.70489298  1.46614071
#   2.37075172  1.38141034  0.95302639  0.15543436  2.12173378  1.18094419
#   0.20896853  1.62182614  0.42579811  2.75343047  2.38229642  4.52187967
#   4.82149062  0.32931722  0.75796884  1.7125903   2.2096541   7.63875966
#   0.71601501  2.19746746  0.20224068  1.8386118   2.6576709   2.17193049
#   1.59927024  1.93139165  0.67663971  2.97782562  2.47000989  2.61837741
#   0.8310453   2.08793405  0.98390336  1.77819833  3.80797812  0.28407118
#   5.55191279  2.34090633  2.19872521  5.60572976  1.71177074  2.05429809
#   1.10311134  2.35980869  6.08275914  1.07570546  3.24938913  0.85064954
#   1.2403199   5.83192973  0.99786595  2.50669694  4.93090852  1.07762266
#   0.24974488  4.65944195  1.21223194  0.55032772  1.37245576  4.02527996
#   1.00089197  0.53222211  3.12011995  6.77915254  0.88115878  1.74167388
#   2.70311913  2.28755131  2.14462021  1.00755807  2.09034713  2.21724826
#   4.5991392   1.53032371  0.80276576  2.89452214  0.19358749  5.31260356
#   4.70437841  4.24369534  2.28705971  2.80834154  3.69148439  1.58342733
#   5.81233644  2.41188707  1.52776187  2.01217009  1.04538728  2.50414614
#   3.07847785  1.96607253  2.76505911  2.00895453  2.5722467   2.05029503
#   0.11533178  0.23417315  3.40110765  2.12019453  0.90309024  1.58453423
#   1.67948939  2.55632324  0.61973985  0.55848301  0.69441494  2.05668425
#   2.26899836  2.53941433  1.14175257  2.83340936  3.41569274  3.03055251
#   1.38100241  2.89769084  2.71360839  1.2425205   0.16218634  1.78939779
#   2.89689629  0.3584368   1.38877469  0.77885474  2.87904338  1.38609338
#   0.74615697  5.06680534  2.04593519  3.90981182  3.43749188  7.69235634
#   0.73417582  2.58673471  3.09603779  0.29858921  0.86614077  6.15654693
#   0.98625545  0.97789917  1.40543654  1.64403299  3.77889274  1.28816842
#   0.35549837  1.58549903  0.11987461  2.2877503   0.97860388  0.5821593
#   2.46913315  4.75045168  0.99341938  2.21268393  1.55333171  0.4563357
#   0.64919357  1.44331335  1.79195007  0.16139475  1.48845706  3.89931661
#   0.76739065  1.23663138  2.02589608  1.64771614  3.38455811  4.56207364
#   3.04401129  2.50037778  1.14293483  2.23922652  0.40921571  3.16475147
#   0.93393273  3.45600149  1.18434398  2.41517898  0.26589824  3.90236148
#   4.09849863  2.60046532  0.79044931  3.28694315  2.43112794  2.00233226
#   0.98508755  3.47463256  3.67178142  1.61542452  0.19834324  3.82933805
#   6.79406127  0.70515805  0.11632326  1.3558869   2.43674293  1.04287059
#   2.83104066  3.31016462  0.97879875  2.32012605  2.34155771  3.97028243
#   2.53074202  2.00029926  3.68344825  4.40805446  6.52159543  1.91920851
#   0.68739533  0.73565722  1.52158246  1.70807512  1.67509163  1.08776358
#   3.96885468  6.90794685  0.80421789  2.97722952  2.11546126  1.29552174
#   2.06810988  4.97820337  1.62737715  1.10052768  0.77753929  2.30254221
#   4.61324234  1.76856462  0.81629699  2.84019058  1.67032122  0.5425217
#   1.63908036  1.48002313  3.32248536  3.91253537  3.35929094  0.70861586
#   1.94474627  3.01752279  1.42470423  1.53582701  1.68230683  1.91432284
#   0.66209645  0.20832578  1.67869825  3.03364278  4.46242256  0.7729548
#   0.90885806  2.65688568  1.80618762  0.71038759  0.97842425  3.71161444
#   1.96520782  1.12858285  0.46941733  2.58589563  0.63302356  0.66277817
#   0.57668669  2.73855606  2.76327748  1.70626038  3.33348019  1.29393325
#   0.93762327  1.40957376  0.51147644  2.65687905  0.43308811  1.01077948
#   0.39453552  2.64262106  0.41911468  0.42871705  3.60359447  1.16958206
#   0.98184974  1.14321695  2.54157115  1.1020473   0.38916677  0.60413356
#   1.39635394  1.67650013  8.04659396  2.64980919  3.9358912   1.69901919
#   0.47651445  3.58637851  1.95054427  2.66581131  1.97482709  4.12301578
#   3.32973107  5.32600565  2.17736906  0.15723086  1.16915833  2.10478252
#   1.81311286  1.50764812  1.35318266  0.01274777  0.34978232  2.56825782
#   3.96660564  1.9198217   1.38729279  5.1323818   1.47849802  1.23518331
#   2.90348346  4.77222541  5.79020622  0.43895332  0.89975182  1.77033928
#   1.48256206  3.47381266  1.55838269  1.44304742  0.68953745  0.68813004
#   2.29943523  3.80534199  0.79864688  1.25693456  3.50685425  0.58981664
#   1.77096221  1.41717725  1.13299246  1.77845337  2.14395622  1.17185456
#   3.70070804  3.50014774  3.84135195  1.69002945  2.19558891  1.92205407
#   0.66645314  1.02207497  0.29187239  1.04051092  3.51288684  1.76474365
#   3.25048323  1.37723003  2.52338079  1.24307342  1.47429703  1.25312646
#   1.30446363  3.47128032  1.23131774  2.61261588  0.76376625  0.32123506
#   1.89575003  0.04230303  3.13113997  2.03371047  3.18043583  1.29574186
#   2.22856031  0.73740375  2.19940493  3.101135    0.37306517  1.03963219
#   1.0795458   3.30328818  0.67612405  2.98788646  2.41611216  2.05018925
#   1.09355905  1.31656141  1.05549943  0.88112101  1.43753277  3.1412051
#   1.78850614  1.07753483  0.76108676  1.84219658  3.92022762  1.49524887
#   2.01882748  1.11640092  2.71892802  1.57892954  4.0882386   0.52568958
#   0.31797893  0.71985038  1.07251575  0.92235125  0.99355438  2.16327457
#   2.03103881  1.25658413  3.24559828  1.08307613  7.22369882  0.45336126
#   4.99140854  4.58664137  2.48316333  0.74200229  0.87417745  1.65436859
#   2.27465528  6.43576006  5.37390516  1.75667374  2.02293955  2.11490843
#   0.6011249   2.01017535  3.07950294  1.68207108  3.50481169  2.73173791
#   1.12936654  0.8930846   0.73114275  3.1401692   2.51915736  2.42804915
#   1.96522293  6.48384381  2.31547143  1.54858787  1.92237992  1.52775589
#   1.82786011  0.50201057  1.64627144  3.13235915  3.73292798  2.53087638
#   4.59965401  2.70881353  2.39853899  0.79083569  1.81398524  2.71473782
#   0.82098625  0.60149655  3.50972419  4.48965796  2.0215524   0.18797679
#   1.26468888  0.72178846  1.38775954  2.47290043  0.35334555  2.11442509
#   2.92570548 10.75356894  2.9310878   0.73542385  1.37492059  1.34895444
#   1.04477387  2.79613642  2.39529717  0.19079536  1.37639991  2.24902459
#   3.41945793  0.67535924  0.35652499  0.84409243  4.11369299  1.13510582
#   0.23564159  0.75389516  2.67433039  1.48802496  0.47551231  3.68582169
#   3.98625173  2.46739317  0.72124441  1.6626135   0.98601185  0.11989725
#   0.46384723  0.26369851  0.12336282  3.34506174  1.99104327  2.42348285
#   4.2607977   1.81927335  1.52966568  0.44439462  2.200349    0.70354518
#   1.85617345  2.24302538  0.33212314  2.70020774  2.12843168  2.7995517
#   2.46725353  0.45494431  2.00557544  3.81918955  1.35582958  0.50451571
#   6.38689392  1.54450717  0.50963098  2.25790197  1.93173738  0.63508576
#   1.85426826  1.06865256  0.96709206  0.78799702  2.89191277  6.28451194
#   1.93465145  2.42423055  2.5339797   0.77545704  1.98476718  3.60326621
#   0.94889684  0.32953366  0.96474483  2.21939339  0.42561744  1.67279127
#   0.42605844  0.84234493  1.5800337   1.2292538   0.83041303  0.76380504
#   1.73422541  2.82778389  5.17058982  3.92610166  1.0839721   0.73567778
#   1.43617088  0.89071661  3.54618201  0.8990271   0.65344402  1.17800552
#   0.75459515  0.78618664  0.81757634  2.28818338  3.70184317  3.46878413
#   1.44861363  7.20137099  1.02790622  0.91455163  1.10099564  1.42401851
#   3.09369153  0.30986889  4.43522138  1.04661407  1.29412848  1.32975524
#   3.55628511  4.19322055  2.23132422  0.01981326  0.51002307  3.08158911
#   0.51742511  3.9230321   1.34771987  1.06857307  1.44287556  5.13214004
#   1.59025809  1.03122504  2.81885705  1.24043556  0.26477528  0.02460536
#   3.55495228  1.17556518  0.41292789  4.10253907  0.93872452  1.7488576
#   0.77080805  0.72258421  1.7514304   1.20788881  1.72137548  1.03461485
#   1.24860133  6.24446103  0.88188057  2.90726101  0.57120983  1.31207886
#   2.62746482  2.51071622  3.45240919  2.82657948  2.82130699  3.05680888
#   1.32171391  1.3749529   1.44923491  1.71291341  2.03856615  2.87915037
#   1.52840132  2.41713247  0.32508259  0.59272793  0.34271706  2.46127442
#   2.75427896  3.05029662  1.77588747  0.7795068   0.14087626  0.4797141
#   1.42860624  1.43523295  1.20565359  0.84573141  0.8414972   4.32979093
#   1.9025159   3.79859627 11.39321792  0.46160943  1.56739412  1.4451774
#   1.40556678  1.62946062  0.73896236  2.76588201  2.38510768  1.80908143
#   4.28474352  0.49938364  8.19519281  1.77662836  1.03830644  0.18486898
#   3.9436293   0.76671638  0.11814206  0.37403964  1.5567903   0.50910517
#   2.62957916  2.78524366  2.17599715  1.52042839  3.39428398  1.84782567
#   0.81506209  0.87703343  1.19799795  1.59128024  1.48333974  4.95632469
#   1.03633023  1.27283675  2.32350514  2.72196984  1.46138406  0.73067201
#   0.98911597  1.42333411  5.13141131  0.73297942  1.34590187  1.46335025
#   1.61393918  0.89839762  0.41224961  0.34572329  0.14864776  3.03884024
#   1.77847817  1.76260725  2.19202849  1.73507318  1.50923497  2.19019602
#   1.86419645  0.69737898  1.94028483  0.98759189  1.38404063  1.63625195
#   0.33191802  3.98326745  1.71779452  5.33292362  4.64836106  2.4983485
#   1.91810158  1.12195608  1.33546022  6.31119175  1.34703554  3.31236764
#   2.58626844  1.67124848  4.76324085  3.71233008  2.30721672  0.66788119
#   2.95242154  1.83473482  2.38731556  0.44832589  1.45692853  1.46899157
#   1.09001827  0.79355252  0.49177736  4.30669765  0.8754802   3.18602455
#   1.00880265  0.17332161  2.48599696  8.89088489  0.26508577  1.46956069
#   2.70442524  7.08930251  1.64398074  5.05736001  4.92488732  2.13147084
#   3.35643514  1.74631193  0.53957113  3.47740136  2.13405181  0.62542573
#   4.81040489  1.29164018  0.21519299  2.15337007  1.32745323  0.84517182
#   2.5568574   0.9781721   2.84929537  1.02002062  0.7846807   2.25424625
#   2.39662055  1.25692253  0.14627788  4.46784072  1.83414374  1.49547182
#   0.42327084  0.28999073  2.23586448  1.67302792  4.16737376  0.81128042
#   0.34370902  1.26799642  3.35964126  1.19424662  0.86512589  4.65717469
#   3.40530857  1.11943972  0.58924999  1.09317337  2.93559485  0.69508512
#   0.55537922  2.46930329  0.50276412  1.18309027  0.63486269  1.51581027
#   1.38189682  3.90482013  1.66820867  1.80686373  1.86433423  0.45994069
#   0.94488238  1.98611241  4.01350208  3.45335672  4.52736915  2.96897772
#   1.99056553  0.70326282  3.49038294  1.78731565  3.21182839  1.378014
#   2.22758083  1.08507725  3.05257062  1.24848031]
# (array([332., 325., 184.,  92.,  38.,  17.,   7.,   3.,   0.,   2.]),
#  array([ 0.01274777,  1.15079479,  2.2888418 ,  3.42688882,  4.56493583,
#          5.70298284,  6.84102986,  7.97907687,  9.11712389, 10.2551709 ,
#         11.39321792]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Central limit theorem
#
# ## Running the example generates and prints the sample of 50 die rolls and the mean value of the sample.

# %%
# generate random dice rolls
from numpy.random import seed
from numpy.random import randint
from numpy import mean
# seed the random number generator
seed(1)
# generate a sample of die rolls
rolls = randint(1, 7, 50)
print(rolls)
print(mean(rolls))
# Out:
# [6 4 5 1 2 4 6 1 1 2 5 6 5 2 3 5 6 3 5 4 5 3 5 6 3 5 2 2 1 6 2 2 6 2 2 1 5
#  2 1 1 6 4 3 2 1 4 6 2 2 4]
# 3.44

# %%
# demonstration of the central limit theorem
from numpy.random import seed
from numpy.random import randint
from numpy import mean
from matplotlib import pyplot
# seed the random number generator
seed(1)
# calculate the mean of 50 dice rolls X times
means1 = [mean(randint(1, 7, 50)) for _ in range(10)]
means2 = [mean(randint(1, 7, 50)) for _ in range(50)]
means3 = [mean(randint(1, 7, 50)) for _ in range(100)]
means4 = [mean(randint(1, 7, 50)) for _ in range(500)]
means5 = [mean(randint(1, 7, 50)) for _ in range(2000)]



# plot the distribution of sample means

pyplot.hist(means5,color='purple')
pyplot.hist(means4,color='blue')
pyplot.hist(means3,color='green')
pyplot.hist(means2,color='red')
pyplot.hist(means1,color='orange')
pyplot.show()

# %%
#SMOTE
# !pip install -U imbalanced-learn

# check version number
import imblearn
# print(imblearn.__version__)

# %%
## OVERSAMPLING

# %%
import imblearn

# %%
# Generate and plot a synthetic imbalanced classification dataset
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from matplotlib import pyplot
from numpy import where
# define dataset
X, y = make_classification(n_samples=900, n_features=2, n_redundant=0,
 n_clusters_per_class=2, weights=[0.99], flip_y=0, random_state=10)
# summarize class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
 row_ix = where(y == label)[0]
 pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# summarize class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 891, 1: 9})
# Counter({0: 891, 1: 9})

# %%
#SMOTE

# %%
# transform the dataset
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
 row_ix = where(y == label)[0]
 pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 891, 1: 891})

# %%
# Adasyn

# %%
from imblearn.over_sampling import ADASYN
# summarize class distribution
counter = Counter(y)
print(counter)
# transform the dataset
oversample = ADASYN()
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
 row_ix = where(y == label)[0]
 pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 891, 1: 891})
# Counter({0: 891, 1: 891})
